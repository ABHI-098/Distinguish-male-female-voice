# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('voice.csv')

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
df.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %%
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
print("No. of male:",format(df[df.label=='male'].shape[0]))
print("No. of female:",format(df[df.label=='female'].shape[0]))
# Out:
# No. of male: 1584
# No. of female: 1584

# %%
X=df.iloc[:,:-1] #col_excLAST
Y=df.iloc[:,-1]
print(df.shape)
print(X.shape)
# Out:
# (3168, 21)
# (3168, 20)

# %%
Y
# Out:
# 0         male
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 3163    female
# 3164    female
# 3165    female
# 3166    female
# 3167    female
# Name: label, Length: 3168, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
gender_enc=LabelEncoder()
Y=gender_enc.fit_transform(Y)
Y
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
scaler=StandardScaler()
scaler.fit(X)
X=scaler.transform(X)
X
# Out:
# array([[-4.04924806,  0.4273553 , -4.22490077, ..., -1.43142165,
#         -1.41913712, -1.45477229],
#        [-3.84105325,  0.6116695 , -3.99929342, ..., -1.41810716,
#         -1.4058184 , -1.01410294],
#        [-3.46306647,  1.60384791, -4.09585052, ..., -1.42920257,
#         -1.41691733, -1.06534356],
#        ...,
#        [-1.29877326,  2.32272355, -0.05197279, ..., -0.5992661 ,
#         -0.58671739,  0.17588664],
#        [-1.2452018 ,  2.012196  , -0.01772849, ..., -0.41286326,
#         -0.40025537,  1.14916112],
#        [-0.51474626,  2.14765111, -0.07087873, ..., -1.27608595,
#         -1.2637521 ,  1.47567886]])

# %%
from sklearn.model_selection import train_test_split as tts
x_tr,x_te,y_tr,y_te=tts(X,Y,test_size=0.21,random_state=100)

# %%
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix

# %%
svc=SVC()
svc.fit(x_tr,y_tr)
y_predict=svc.predict(x_te)
print("accuracy score:",metrics.accuracy_score(y_te,y_predict))
# Out:
# accuracy score: 0.9774774774774775
# D:\ANACONDA\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
print(confusion_matrix(y_te,y_predict))
# Out:
# [[327  10]
#  [  5 324]]

# %%
print(classification_report(y_te,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       337
#            1       0.97      0.98      0.98       329
#
#     accuracy                           0.98       666
#    macro avg       0.98      0.98      0.98       666
# weighted avg       0.98      0.98      0.98       666

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.1,1,10,100],'gamma':[1,0.1,0.01,0.001]}
grid=GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(x_tr,y_tr)
# Out:
# D:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.4s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV] ................................... C=0.1, gamma=1, total=   0.3s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.4s
# [CV] C=0.1, gamma=0.1 ................................................
# ...

# %%
grid_pred=grid.predict(x_te)
print('New accuracy score:',metrics.accuracy_score(y_te,grid_pred))
# Out:
# New accuracy score: 0.975975975975976

# %%
print("array[0] means: male\narray[1] means: female")
grid.predict([[0.059780985,0.064241268,0.032026913,0.015071489,0.09019344,0.075121951,12.86346184,274.4029055,0.893369417,0.491917766,0,0.059780985,0.084279106,0.015701668,0.275862069,0.0078125,0.0078125,0.0078125,0,0
]])
# Out:
# array[0] means: male
# array[1] means: female
# array([0], dtype=int64)
